# %%
#those words in oputput cannot be used as variable name 
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
name="Ayush"
age=21
city="Indore"
print(f"My name is {name} and age is {age} and i live in {city}")
print("My name is {} and age is {}".format(name,age))
# Out:
# My name is Ayush and age is 21 and i live in Indore
# My name is Ayush and age is 21

# %%
#1. Print the result of 25 + 75
print(25+75)
# Out:
# 100

# %%
#2. Print the result of 50 - 18.
print(50-18)
# Out:
# 32

# %%
#3. Create two variables a = 15 and b = 5. Print their sum.
a=15
b=5
sum=a+b
print(sum)
# Out:
# 20

# %%
#4. Create two variables x = 20 and y = 4. Print their division.
x=20
y=4
div=x/y
print(div)
# Out:
# 5.0

# %%
#5. Create variables length = 10 and width = 6. Calculate and print the perimeter of a rectangle.
length=10
width=6
perimeter=length*width
print(perimeter)
# Out:
# 60

# %%
#6. Create variable price = 250 and quantity = 3. Print total cost.
price=250
quantity=3
total_cost=price*quantity
print(total_cost)
# Out:
# 750

# %%
#7. Calculate and print the square of 12. Add a comment explaining the code.
num=12 #this is variable 
squareroot=num*num #here we are calculating the square root of given number
print(f"Square root of {num} is {squareroot}")
# Out:
# Square root of 12 is 144

# %%
#8. Write multi line comment (Hello;This is a multi-line comment;Bye) and print Hello
"""
Hello
This is a multi line comment 
bye.
"""
print("Hello")
# Out:
# Hello

# %%
#9. Print your name, surname, hobby, weight, No. of siblings in a form of paragraph.
name="Raghvendra"
surname="Mishra"
hobby="Travelling"
weight=66
siblings=2
print(f"Hey Everyone, My name is {name}{surname} and my body weight is {weight}.\nOne of my most favorate hobby is {hobby} which I do mostly solo trips but sometimes I also travelled with my {siblings} siblings.")
# Out:
# Hey Everyone, My name is RaghvendraMishra and my body weight is 66.
# One of my most favorate hobby is Travelling which I do mostly solo trips but sometimes I also travelled with my 2 siblings

# %%
#10. what will be the output of (2 + 3 * 4) and ((2 + 3) * 4)
solution1=(2+3*4)
print(solution1)
solution2=((2 + 3) * 4)
print(solution2)
# Out:
# 14
# 20
